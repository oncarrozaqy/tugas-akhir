# %%
import pandas as pd
import numpy as np

# %%
# import os

# for s in range(1, 30):
#     if s >= 26:
#         continue
#     folder_path = f'S{s}'
#     for i in range(1, 12):
#         old_file_name = f'S{s}.task{i}.csv'
#         new_file_name = f'S{s}_task{i}.csv'
#         old_file_path = os.path.join(folder_path, old_file_name)
#         new_file_path = os.path.join(folder_path, new_file_name)
#         os.rename(old_file_path, new_file_path)

# %%
# s30_1 = pd.read_csv('S30/Autumyaeyeopen.csv', header=None)
# s30_1

# %%
# import os

# # List all files in the S30 folder
# folder_path = 'S30'
# csv_files = [f for f in os.listdir(folder_path) if f.endswith('.csv')]

# # Print the list of CSV files
# print(csv_files)

# %%
# import os

# # Folder yang berisi file CSV
# folder_path = "S30"

# # List nama file asli dan mapping ke task
# file_mapping = {
#     "Autumyeyeclose.csv": "task1",
#     "Autumyaeyeopen.csv": "task2",
#     "Autumyhappy.csv": "task3",
#     "Autumycalm.csv": "task4",
#     "Autumysad.csv": "task5",
#     "Autumyfear.csv": "task6",
#     "Autumymomorise.csv": "task7",
#     "Autumyexcutive.csv": "task8",
#     "Autumyrecall.csv": "task9",
#     "Autumyeyecloseextend.csv": "task10",
#     "Autumyeyeopenextend.csv": "task11",
# }

# # Loop untuk mengganti nama file
# for original_name, task_name in file_mapping.items():
#     original_path = os.path.join(folder_path, original_name)
#     new_name = f"S30_{task_name}.csv"
#     new_path = os.path.join(folder_path, new_name)

#     # Rename file jika file asli ada di folder
#     if os.path.exists(original_path):
#         os.rename(original_path, new_path)
#         print(f"Renamed: {original_name} -> {new_name}")
#     else:
#         print(f"File not found: {original_name}")

# %%
# Read S30
s30 = pd.read_csv('S30/S30_task1.csv', header=None)
s30.head()
# Out:
#    0                                   1           2   3   4      5      6   \
# 0   0  Wed Apr 28 13:45:31 GMT+08:00 2021  1619588731  67  16  10810  20559
# 1   1  Wed Apr 28 13:45:32 GMT+08:00 2021  1619588732  70  16   7605   8658
# 2   2  Wed Apr 28 13:45:33 GMT+08:00 2021  1619588733  78  26  28300  44633
# 3   3  Wed Apr 28 13:45:34 GMT+08:00 2021  1619588734  80  34  36109  26195
# 4   4  Wed Apr 28 13:45:35 GMT+08:00 2021  1619588735  80  53  52277  15075
#
#       7      8       9       10     11     12
# 0  38175  14694  594932   70203  20720  21835
# 1   5944   3902  123326   40090   4824   6832
# 2  16940  20034  489210   89138  24669  37010
# 3  20327  22141  404766  214787  15803  22806
# 4  21590  17274  548810   36585  27531  17737

# %%
dataframes = {}
for i in range(1, 30):
    for j in range(1, 12):
        df_name = f's{i}_task{j}'
        file_path = f'S{i}/S{i}_task{j}.csv'
        df = pd.read_csv(file_path, header=None)
        df.columns = ['attention', 'meditation', 'LowAlpha', 'HighAlpha', 'LowBeta', 'HighBeta', 'Delta', 'Theta', 'LowGamma', 'MiddleGamma']
        dataframes[df_name] = df

# Case khusus S30
for j in range(1, 12):
    df_name = f's30_task{j}'
    file_path = f'S30/S30_task{j}.csv'
    df = pd.read_csv(file_path, header=None)
    df = df.drop([0, 1, 2], axis=1)
    df.columns = ['attention', 'meditation', 'LowAlpha', 'HighAlpha', 'LowBeta', 'HighBeta', 'Delta', 'Theta', 'LowGamma', 'MiddleGamma']
    dataframes[df_name] = df
    
# Example to access a specific dataframe
dataframes['s30_task1'].head()
# Out:
#    attention  meditation  LowAlpha  HighAlpha  LowBeta  HighBeta   Delta  \
# 0         67          16     10810      20559    38175     14694  594932
# 1         70          16      7605       8658     5944      3902  123326
# 2         78          26     28300      44633    16940     20034  489210
# 3         80          34     36109      26195    20327     22141  404766
# 4         80          53     52277      15075    21590     17274  548810
#
#     Theta  LowGamma  MiddleGamma
# 0   70203     20720        21835
# 1   40090      4824         6832
# 2   89138     24669        37010
# 3  214787     15803        22806
# 4   36585     27531        17737

# %%
# Lakukan EDA untuk dataframes keseluruhan, bukan per subjek
# Gabungkan semua dataframes menjadi satu dataframe, namun berikan label subjek dan task
df_all = pd.concat(dataframes, names=['subjek_task'])
df_all
# Out:
#                 attention  meditation  LowAlpha  HighAlpha  LowBeta  HighBeta  \
# subjek_task
# s1_task1    0          34          69     25137      10967     2604      5321
#             1          43          74     15167      34062    17446     16113
#             2          61          64      5726       4932     2482      6996
#             3          57          64     24948      14535    30571     15185
#             4          66          57      5626       6658     6843      4939
# ...                   ...         ...       ...        ...      ...       ...
# s30_task11  57         44          83     81951      94905    39206     22496
#             58         37          93     27860     212231    18418     13025
#             59         47          87      5462      10772     4803      2560
#             60         37          67     29540      27635     2256      7036
#             61         41          61      5081      16029     5536      7301
#
#                  Delta   Theta  LowGamma  MiddleGamma
# subjek_task
# s1_task1    0    25031   37279      1725         2549
#             1    49284   52473     31642         7755
#             2   139747   18902      7644         3362
#             3   228001  124834     13174         7611
#             4   260240   23033      3564         3302
# ...                ...     ...       ...          ...
# s30_task11  57  103254  108990     24667         4548
#             58   78108   55754      4578         3073
#             59  571862   24237       714          678
#             60  125398  141177      1597          591
#             61  292385   33621      1489         2403
#
# [21649 rows x 10 columns]

# %%
# Count null value dari setiap atribut df_all
df_all.isnull().sum()
# Out:
# attention      0
# meditation     0
# LowAlpha       0
# HighAlpha      0
# LowBeta        0
# HighBeta       0
# Delta          0
# Theta          0
# LowGamma       0
# MiddleGamma    0
# dtype: int64

# %%
import seaborn as sns

import matplotlib.pyplot as plt

# Deskripsi statistik
print(df_all.describe())

# Visualisasi distribusi untuk setiap kolom
df_all.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# Visualisasi distribusi menggunakan seaborn
plt.figure(figsize=(15, 10))
for i, column in enumerate(df_all.columns, 1):
    plt.subplot(3, 4, i)
    sns.histplot(df_all[column], kde=True)
    plt.title(f'Distribution of {column}')
plt.tight_layout()
plt.show()

# Heatmap korelasi
plt.figure(figsize=(12, 8))
correlation_matrix = df_all.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Matrix')
plt.show()

# Pairplot untuk melihat hubungan antar variabel
sns.pairplot(df_all.sample(500))  # Menggunakan sampel untuk mempercepat proses
plt.show()

# Boxplot untuk melihat distribusi dan outliers
plt.figure(figsize=(15, 10))
for i, column in enumerate(df_all.columns, 1):
    plt.subplot(3, 4, i)
    sns.boxplot(y=df_all[column])
    plt.title(f'Boxplot of {column}')
plt.tight_layout()
plt.show()

# Deskripsi statistik dalam bentuk tabel
desc_table = df_all.describe().transpose()
print(desc_table)

# Simpan deskripsi statistik sebagai gambar
plt.figure(figsize=(12, 6))
plt.axis('off')
tbl = plt.table(cellText=desc_table.values, colLabels=desc_table.columns, rowLabels=desc_table.index, cellLoc='center', loc='center')
tbl.auto_set_font_size(False)
tbl.set_fontsize(10)
tbl.scale(1.2, 1.2)
plt.savefig('deskripsi_statistik.png', bbox_inches='tight', dpi=300)
plt.show()
# Out:
#           attention    meditation       LowAlpha     HighAlpha       LowBeta  \
# count  21649.000000  21649.000000   21649.000000  2.164900e+04  2.164900e+04
# mean      51.443669     53.815557   29433.054414  2.898359e+04  1.651351e+04
# std       22.142261     19.435250   49221.141970  4.927936e+04  2.530247e+04
# min        1.000000      1.000000       0.000000  1.000000e+00  0.000000e+00
# 25%       37.000000     41.000000    6875.000000  7.456000e+03  6.090000e+03
# 50%       51.000000     53.000000   14989.000000  1.502900e+04  1.108700e+04
# 75%       67.000000     66.000000   31803.000000  3.066100e+04  1.931500e+04
# max      100.000000    100.000000  911778.000000  1.088949e+06  1.578578e+06
#
#            HighBeta         Delta         Theta      LowGamma   MiddleGamma
# count  2.164900e+04  2.164900e+04  2.164900e+04  2.164900e+04  2.164900e+04
# mean   1.946841e+04  3.481275e+05  9.919480e+04  1.281392e+04  4.216701e+04
# std    3.711536e+04  5.083721e+05  1.874121e+05  2.641586e+04  1.874525e+05
# min    1.000000e+00  1.500000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%    6.841000e+03  2.326400e+04  1.744700e+04  3.896000e+03  2.681000e+03
# 50%    1.175500e+04  1.239440e+05  3.906200e+04  7.088000e+03  5.729000e+03
# 75%    2.006200e+04  4.551440e+05  9.653900e+04  1.310300e+04  1.288600e+04
# max    1.253469e+06  3.853839e+06  3.208039e+06  1.189665e+06  2.291689e+06
#                count           mean            std   min      25%       50%  \
# attention    21649.0      51.443669      22.142261   1.0     37.0      51.0
# meditation   21649.0      53.815557      19.435250   1.0     41.0      53.0
# LowAlpha     21649.0   29433.054414   49221.141970   0.0   6875.0   14989.0
# HighAlpha    21649.0   28983.594947   49279.356795   1.0   7456.0   15029.0
# LowBeta      21649.0   16513.511756   25302.474118   0.0   6090.0   11087.0
# HighBeta     21649.0   19468.414523   37115.364808   1.0   6841.0   11755.0
# Delta        21649.0  348127.522611  508372.126478  15.0  23264.0  123944.0
# Theta        21649.0   99194.799436  187412.109709   0.0  17447.0   39062.0
# LowGamma     21649.0   12813.924292   26415.862045   0.0   3896.0    7088.0
# MiddleGamma  21649.0   42167.008961  187452.459167   0.0   2681.0    5729.0
#
#                   75%        max
# attention        67.0      100.0
# meditation       66.0      100.0
# LowAlpha      31803.0   911778.0
# HighAlpha     30661.0  1088949.0
# LowBeta       19315.0  1578578.0
# HighBeta      20062.0  1253469.0
# Delta        455144.0  3853839.0
# Theta         96539.0  3208039.0
# LowGamma      13103.0  1189665.0
# MiddleGamma   12886.0  2291689.0

# %%
# Read resultcombine.xlsx
result = pd.read_excel('ResultCombine.xlsx')
result['Internet Addiction Result'].value_counts()
# Out:
# Internet Addiction Result
# Mid Level         18
# Moderate level     7
# Normal Level       4
# Severe Level       1
# Name: count, dtype: int64
